# %% [markdown]
# # IMPORTING LIBRARIES

# %%
from  scipy import stats
from scipy.stats import norm, skewnorm
import matplotlib.pyplot as plt

# %% [markdown]
# # NORMALIZED DATA

# %%
data = norm.rvs(size=1000)

# %%
plt.hist(data, bins = 20)
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
fig, ax = plt.subplots()
stats.probplot(data, fit = True, plot = ax)
plt.show()

# %%
stats.shapiro(data)
# Out:
# ShapiroResult(statistic=0.9989117383956909, pvalue=0.824346661567688)

# %% [markdown]
# The P-value is more than 0.05 so we can confirm that the dataset has normalized values.

# %% [markdown]
# # NON NORMALIZED DATA

# %%
data2 = skewnorm.rvs(4, size = 1000)

# %%
plt.hist(data2, bins = 20)
# Out:
# (array([  8.,  48.,  99., 134., 160., 141., 115., 101.,  62.,  57.,  35.,
#          14.,  11.,   4.,   6.,   0.,   2.,   2.,   0.,   1.]),
#  array([-0.55211319, -0.31678582, -0.08145845,  0.15386892,  0.38919628,
#          0.62452365,  0.85985102,  1.09517839,  1.33050576,  1.56583313,
#          1.8011605 ,  2.03648787,  2.27181523,  2.5071426 ,  2.74246997,
#          2.97779734,  3.21312471,  3.44845208,  3.68377945,  3.91910682,
#          4.15443418]),
#  <BarContainer object of 20 artists>)

# %%
fig, ax = plt.subplots()
stats.probplot(data2, fit = True, plot = ax)
plt.show()

# %%
stats.shapiro(data2)
# Out:
# ShapiroResult(statistic=0.9678584337234497, pvalue=4.594820685499719e-14)

# %% [markdown]
# The P-value is less than 0.05 so we can confirm that the dataset does not have normalized values.
